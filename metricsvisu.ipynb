# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
metrics_label = ['Accuracy', 'F1', 'Specificity', 'Sensitivity', 'Precision']
gd = []
sgd = []
ls = []
ridge = []
logisti = []
reg_logistic = []

Zboys = [20, 30, 25, 30]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, Ygirls, 0.4, label='Girls')
plt.bar(X_axis + 0.2, Zboys, 0.4, label='Boys')

# Add value annotations on top of each bar
for i, value in enumerate(Ygirls):
    plt.text(X_axis[i] - 0.2, value + 0.5, str(value), ha='center', va='bottom')

for i, value in enumerate(Zboys):
    plt.text(X_axis[i] + 0.2, value + 0.5, str(value), ha='center', va='bottom')

plt.xticks(X_axis, X)
plt.xlabel("Groups")
plt.ylabel("Number of Students")
plt.title("Number of Students in each group")
plt.legend()
plt.show()
